# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset/Mlbb_Heroes.csv')
df
# Out:
#             Name             Title
# 0          Aamon    Duke of Shards  \
# 1           Akai     Panda Warrior
# 2         Aldous   Soul Contractor
# 3          Alice    Queen of Blood
# 4          Alpha   Blade of Enmity
# ..           ...               ...
# 109  Yi_Sun-Shin   Paenlong Legend
# 110     Yu_Zhong      Black Dragon
# 111          Yve       Astrowarden
# 112        Zhask  Planes Dominator
# 113       Zilong   Spear of Dragon
#
#                                             Voice_Line Release_Date
# 0    It is better to be feared than loved, if you c...   2021-10-25  \
# 1                           Now Akai enters the scene!         2016
# 2                                         Primary Role         2018
# 3                                     Watch your back!         2016
# 4                               Test! Alpha is online.         2017
# ..                                                 ...          ...
# 109                                     Secondary Role         2017
# 110  I would rather betray the world, than let the ...   2020-06-19
# 111  Among the planes exists the equilibrium, which...   2021-02-12
# 112                    Grovel before your King, human!   2017-11-27
# 113                            The Dragonborn is back!         2016
#
#     Primary_Role Secondary_Role       Lane    Hp  Hp_Regen  Mana  Mana_Regen
# 0       Assassin            NaN    Jungler  2614      8.00   455       21.00  \
# 1           Tank        Support     Roamer  2769      8.40   422       12.00
# 2        Fighter            NaN   EXP Lane  2718      9.80   405       18.00
# 3           Mage           Tank   EXP Lane  2573      7.20   493       18.00
# 4        Fighter            NaN   EXP Lane  2646      7.80   453       31.00
# ..           ...            ...        ...   ...       ...   ...         ...
# 109     Assassin       Marksman    Jungler  2570      7.20   438       15.00
# 110      Fighter            NaN   EXP Lane  2698     11.80     0        0.00
# 111         Mage            NaN        Mid  2651      7.20   510       21.00
# 112         Mage            NaN        Mid  2401      6.80   490       20.00
# 113      Fighter       Assassin  Gold Lane  2689      7.00   405       16.00
#
#      Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins
# 0           115           0           19           15        250           43  \
# 1           115           0           24           15        260          540
# 2           129           0           21           15        260           95
# 3           114           0           21           15        240          364
# 4           121           0           25           15        260           24
# ..          ...         ...          ...          ...        ...          ...
# 109         100           0           22           15        250          443
# 110         129           0           21           15        245          550
# 111         115           0           19           15        255          834
# 112         107           0           15           15        240           37
# 113         123           0           25           15        265            5
#
#      Esport_Loss
# 0             42
# 1            524
# 2             92
# 3            352
# 4             33
# ..           ...
# 109          383
# 110          594
# 111          722
# 112           46
# 113           23
#
# [114 rows x 18 columns]

# %%
df['Hero_Defense'] = df['Mag_Defence'] + df['Phy_Defence']

# %%
# Atur opsi tampilan angka desimal
pd.set_option('display.float_format', '{:.2f}'.format)
# Gunakan describe()
df.describe()
# Out:
#            Hp  Hp_Regen   Mana  Mana_Regen  Phy_Damage  Mag_Damage
# count  114.00    114.00 114.00      113.00      114.00      114.00  \
# mean  2577.85      7.70 339.37       14.93      115.93        0.00
# std    213.28      1.64 215.07       22.98        9.83        0.00
# min    918.00      3.80   0.00        0.00       90.00        0.00
# 25%   2501.00      6.80 100.00        4.00      110.00        0.00
# 50%   2573.00      7.20 436.50       15.00      116.50        0.00
# 75%   2706.25      8.00 490.00       18.00      122.50        0.00
# max   2909.00     18.40 750.00      240.00      140.00        0.00
#
#        Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  Esport_Loss
# count       114.00       114.00     114.00       114.00       114.00  \
# mean         19.20        14.91     251.18       289.86       289.71
# std           3.58         0.66       8.67       275.36       273.14
# min          10.00        10.00     240.00         0.00         3.00
# 25%          17.00        15.00     240.00        68.25        71.75
# 50%          19.00        15.00     251.00       226.50       222.50
# 75%          22.00        15.00     260.00       465.00       457.75
# max          27.00        15.00     270.00      1357.00      1529.00
#
#        Hero_Defense
# count        114.00
# mean          34.11
# std            3.66
# min           25.00
# 25%           32.00
# 50%           34.00
# 75%           37.00
# max           42.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            114 non-null    object
#  1   Title           114 non-null    object
#  2   Voice_Line      114 non-null    object
#  3   Release_Date    114 non-null    object
#  4   Primary_Role    114 non-null    object
#  5   Secondary_Role  30 non-null     object
#  6   Lane            114 non-null    object
#  7   Hp              114 non-null    int64
#  8   Hp_Regen        114 non-null    float64
#  9   Mana            114 non-null    int64
#  10  Mana_Regen      113 non-null    float64
#  11  Phy_Damage      114 non-null    int64
#  12  Mag_Damage      114 non-null    int64
#  13  Phy_Defence     114 non-null    int64
#  14  Mag_Defence     114 non-null    int64
#  15  Mov_Speed       114 non-null    int64
#  16  Esport_Wins     114 non-null    int64
#  17  Esport_Loss     114 non-null    int64
#  18  Hero_Defense    114 non-null    int64
# dtypes: float64(2), int64(10), object(7)
# memory usage: 17.0+ KB

# %%
print(df['Lane'].value_counts(),'\n')
print(df['Primary_Role'].value_counts())
# Out:
# Lane
# EXP Lane     34
# Mid          23
# Gold Lane    21
# Roamer       20
# Jungler      16
# Name: count, dtype: int64
#
# Primary_Role
# Fighter     33
# Mage        25
# Marksman    18
# Tank        16
# Assassin    13
# Support      9
# Name: count, dtype: int64

# %% [markdown]
# Hard Engage = AD + MV <br>
# Team Fight = AD + HP + PD

# %%
df['Hard_Engage'] = (df['Phy_Damage'] + df['Mov_Speed'])
df['Team_Fight'] = (df['Phy_Damage'] + df['Hp'] + df['Phy_Defence'])

# %%
exp = df[df['Lane'] == 'EXP Lane']
exp.head()
# Out:
#       Name                Title                                 Voice_Line
# 2   Aldous      Soul Contractor                               Primary Role  \
# 3    Alice       Queen of Blood                           Watch your back!
# 4    Alpha      Blade of Enmity                     Test! Alpha is online.
# 7    Argus           Dark Angel                               Primary Role
# 10   Aulus  Warrior of Ferocity  Old Aulus still has a few tricks to show!
#
#    Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana
# 2          2018      Fighter            NaN  EXP Lane  2718      9.80   405  \
# 3          2016         Mage           Tank  EXP Lane  2573      7.20   493
# 4          2017      Fighter            NaN  EXP Lane  2646      7.80   453
# 7          2017      Fighter            NaN  EXP Lane  2628      8.00     0
# 10   2021-08-31      Fighter            NaN  EXP Lane  2758     10.20   410
#
#     ...  Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed
# 2   ...         129           0           21           15        260  \
# 3   ...         114           0           21           15        240
# 4   ...         121           0           25           15        260
# 7   ...         100           0           21           15        260
# 10  ...          90           0           24           15        255
#
#     Esport_Wins  Esport_Loss  Hero_Defense  Hard_Engage  Team_Fight
# 2            95           92            36          389        2868
# 3           364          352            36          354        2708
# 4            24           33            40          381        2792
# 7             2            7            36          360        2749
# 10          114          109            39          345        2872
#
# [5 rows x 21 columns]

# %%
mid = df[df['Lane'] == 'Mid']
mid.head()
# Out:
#         Name                 Title
# 9     Aurora          Frost Oracle  \
# 22  Cecilion      Embrace of Night
# 23   Chang'e  Moon Palace Immortal
# 27   Cyclops     Starsoul Magician
# 33    Eudora      Lightning Weaver
#
#                                           Voice_Line Release_Date
# 9                    Listen to the sound of snowing.   09-05-2017  \
# 22              Only love and night are everlasting.   2020-02-12
# 23                                      Primary Role   2018-05-30
# 27                                      Primary Role         2017
# 33  You should be ashamed for not trusting yourself.         2016
#
#    Primary_Role Secondary_Role Lane    Hp  Hp_Regen  Mana  ...  Phy_Damage
# 9          Mage            NaN  Mid  2501      6.80   750  ...         110  \
# 22         Mage            NaN  Mid  2456      6.80   700  ...         105
# 23         Mage            NaN  Mid  2301      6.80   505  ...         115
# 27         Mage            NaN  Mid  2521      7.60   500  ...         112
# 33         Mage            NaN  Mid  2524      7.60   468  ...         112
#
#     Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  Esport_Loss
# 9            0           17           15        245           28           26  \
# 22           0           18           15        255          470          588
# 23           0           16           15        240          221          285
# 27           0           18           15        240           69           90
# 33           0           19           15        250           78           67
#
#     Hero_Defense  Hard_Engage  Team_Fight
# 9             32          355        2628
# 22            33          360        2579
# 23            31          355        2432
# 27            33          352        2651
# 33            34          362        2655
#
# [5 rows x 21 columns]

# %%
gold = df[df['Lane'] == 'Gold Lane']
gold.head()
# Out:
#        Name              Title                                Voice_Line
# 16  Beatrix  Dawnbreak Soldier  Time and tide wait for no man, not girl.  \
# 19    Brody      The Lone Star    Pain is the proof the I'm still alive.
# 20    Bruno     Mech Protector                              Primary Role
# 24     Chou        Kung-Fu Boy                              Primary Role
# 25   Claude  Partners in Crime        Come on Dexter, it's our showtime!
#
#    Release_Date Primary_Role Secondary_Role       Lane    Hp  Hp_Regen  Mana
# 16   2021-03-19     Marksman            NaN  Gold Lane  2550      7.20     0  \
# 19   2020-10-16     Marksman            NaN  Gold Lane  2490      7.20   435
# 20         2016     Marksman            NaN  Gold Lane  2522      6.00   439
# 24         2016      Fighter            NaN  Gold Lane  2708      7.80     0
# 25   2018-08-07     Marksman            NaN  Gold Lane  2370      8.00   450
#
#     ...  Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed
# 16  ...         102           0           20           15        257  \
# 19  ...         105           0           20           15        253
# 20  ...         140           0           17           15        240
# 24  ...         121           0           23           15        260
# 25  ...          97           0           14           15        240
#
#     Esport_Wins  Esport_Loss  Hero_Defense  Hard_Engage  Team_Fight
# 16         1016          969            35          359        2672
# 19          470          476            35          358        2615
# 20          154          154            32          380        2679
# 24         1139         1057            38          381        2852
# 25          618          583            29          337        2481
#
# [5 rows x 21 columns]

# %%
roamer = df[df['Lane'] == 'Roamer']
roamer.head()
# Out:
#         Name               Title
# 1       Akai       Panda Warrior  \
# 6     Angela           Bunnylove
# 8      Atlas     Ocean Gladiator
# 17  Belerick     Guard of Nature
# 21  Carmilla  Shadow of Twilight
#
#                                            Voice_Line Release_Date
# 1                          Now Akai enters the scene!         2016  \
# 6                                        Primary Role   2018-02-06
# 8   The ocean is not just our home. It is who we are.   2020-03-20
# 17                                       Primary Role   2018-12-17
# 21                            True love is like blood   2020-01-17
#
#    Primary_Role Secondary_Role    Lane    Hp  Hp_Regen  Mana  ...  Phy_Damage
# 1          Tank        Support  Roamer  2769      8.40   422  ...         115  \
# 6       Support            NaN  Roamer  2421      6.80   515  ...         115
# 8          Tank        Support  Roamer  2819      8.40   440  ...         135
# 17         Tank            NaN  Roamer  2569      8.40   450  ...         110
# 21      Support            NaN  Roamer  2528      7.80   430  ...         126
#
#     Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  Esport_Loss
# 1            0           24           15        260          540          524  \
# 6            0           15           15        240          253          325
# 8            0           21           15        240          277          254
# 17           0           15           15        250           57           71
# 21           0           25           15        255           32           47
#
#     Hero_Defense  Hard_Engage  Team_Fight
# 1             39          375        2908
# 6             30          355        2551
# 8             36          375        2975
# 17            30          360        2694
# 21            40          381        2679
#
# [5 rows x 21 columns]

# %%
jungler = df[df['Lane'] == 'Jungler']
jungler.head()
# Out:
#        Name            Title
# 0     Aamon   Duke of Shards  \
# 5   Alucard     Demon Hunter
# 13     Bane      Frozen King
# 15    Baxia  Mystic Tortoise
# 34    Fanny     Blade Dancer
#
#                                            Voice_Line Release_Date
# 0   It is better to be feared than loved, if you c...   2021-10-25  \
# 5   Demons shall bathe in their blood. The light b...         2016
# 13                                      Target locked         2016
# 15            Rocks need no protection from the rain.   2019-10-08
# 34                          Sir, what's your command?         2016
#
#    Primary_Role Secondary_Role     Lane    Hp  Hp_Regen  Mana  ...
# 0      Assassin            NaN  Jungler  2614      8.00   455  ...  \
# 5       Fighter       Assassin  Jungler  2621      7.80     0  ...
# 13      Fighter           Mage  Jungler  2559      8.40   433  ...
# 15         Tank            NaN  Jungler  2769      8.40   422  ...
# 34     Assassin            NaN  Jungler  2526      6.60   100  ...
#
#     Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins
# 0          115           0           19           15        250           43  \
# 5          123           0           21           15        260           22
# 13         117           0           23           15        260           95
# 15         125           0           23           15        240          450
# 34         126           0           19           15        265          189
#
#     Esport_Loss  Hero_Defense  Hard_Engage  Team_Fight
# 0            42            34          365        2748
# 5            33            36          383        2765
# 13          111            38          377        2699
# 15          465            38          365        2917
# 34          196            34          391        2671
#
# [5 rows x 21 columns]

# %% [markdown]
# Hard Engage
# Attack Defense + Movement Speed

# %%
# EXP
he_exp_max = exp['Hard_Engage'].max()
hero_exp_max = exp[exp['Hard_Engage'] == he_exp_max]['Name'].iloc[0]
print('Nama:',hero_exp_max)
print('Skor:', he_exp_max)
# Out:
# Nama: Barats
# Skor: 403

# %%
he_mid_max = mid['Hard_Engage'].max()
hero_mid_max = mid[mid['Hard_Engage'] == he_mid_max]['Name'].iloc[0]
print('Nama:',hero_mid_max)
print('Skor:', he_mid_max)
# Out:
# Nama: Yve
# Skor: 370

# %%
he_gold_max = gold['Hard_Engage'].max()
hero_gold_max = gold[gold['Hard_Engage'] == he_gold_max]['Name'].iloc[0]
print('Nama:',hero_gold_max)
print('Skor:', he_gold_max)
# Out:
# Nama: Zilong
# Skor: 388

# %%
he_roamer_max = roamer['Hard_Engage'].max()
hero_roamer_max = roamer[roamer['Hard_Engage'] == he_roamer_max]['Name'].iloc[0]
print('Nama:',hero_roamer_max)
print('Skor:', he_roamer_max)
# Out:
# Nama: Grock
# Skor: 395

# %%
he_jungler_max = jungler['Hard_Engage'].max()
hero_jungler_max = jungler[jungler['Hard_Engage'] == he_jungler_max]['Name'].iloc[0]
print('Nama:',hero_jungler_max)
print('Skor:', he_jungler_max)
# Out:
# Nama: Fanny
# Skor: 391

# %%
max_fv = he_exp_max + he_mid_max + he_gold_max+he_roamer_max+he_jungler_max
max_fv
# Out:
# 1947

# %%
sns.countplot(data=df, x='Primary_Role', palette='muted')
plt.show()
# Out:
# C:\Users\Mufti Alroaz\AppData\Local\Temp\ipykernel_8128\894676384.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Primary_Role', palette='muted')

# %%
sns.countplot(data=df, x='Lane', palette='muted')
plt.show()
# Out:
# C:\Users\Mufti Alroaz\AppData\Local\Temp\ipykernel_8128\3600760716.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Lane', palette='muted')

# %%
df.hist(figsize=(12, 8), edgecolor='black', grid=False)
plt.tight_layout()
plt.show()

# %%
correlation = df['Esport_Wins'].corr(df['Phy_Damage'])
print(f"Korelasi antara Esport_Wins dan Primary_Role: {correlation}")
# Out:
# Korelasi antara Esport_Wins dan Primary_Role: -0.05819912546323813
